# %%
import random

number_of_tosses = int(input("How many times would you like to toss the coin? "))

cards = ["Ace", "2", "3", "4", "5", "6", "7", "8", "9", "10", "Jack", "Queen", "King"]
random.shuffle(cards)

for i in range(random.randint(1, number_of_tosses)):
    print(f"Toss {i + 1}: {random.choice(['Heads', 'Tails'])}")

for card in cards:
    print(f"Card: {card}")
# Out:
# Toss 1: Heads
# Toss 2: Heads
# Toss 3: Tails
# Toss 4: Heads
# Card: 7
# Card: Jack
# Card: 8
# Card: 10
# Card: Ace
# Card: Queen
# Card: 5
# Card: 3
# Card: 4
# Card: 2
# Card: King
# Card: 6
# Card: 9

# %%
import requests
import json

song_name = input("What is the song name? ")

response = requests.get(
    "https://itunes.apple.com/search?entity=song&limit=1&term=" + song_name
).json()

print(json.dumps(response, indent=2))
# Out:
# {
#   "resultCount": 1,
#   "results": [
#     {
#       "wrapperType": "track",
#       "kind": "song",
#       "artistId": 1548567612,
#       "collectionId": 1795667814,
#       "trackId": 1795667819,
#       "artistName": "AFUSIC & AliSoomroMusic",
#       "collectionName": "Pal Pal - Single",
#       "trackName": "Pal Pal",
#       "collectionCensoredName": "Pal Pal - Single",
#       "trackCensoredName": "Pal Pal",
#       "artistViewUrl": "https://music.apple.com/us/artist/afusic/1548567612?uo=4",
#       "collectionViewUrl": "https://music.apple.com/us/album/pal-pal/1795667814?i=1795667819&uo=4",
#       "trackViewUrl": "https://music.apple.com/us/album/pal-pal/1795667814?i=1795667819&uo=4",
#       "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview221/v4/fe/3b/66/fe3b660b-5bca-34e0-14b7-c0a433f3673d/mzaf_2299281302761399301.plus.aac.p.m4a",
#       "artworkUrl30": "https://is1-ssl.mzstatic.com/image/thumb/Music221/v4/c8/cc/e8/c8cce868-9342-d78c-fec5-9d9e5b44106a/25UMGIM17787.rgb.jpg/30x30bb.jpg",
#       "artworkUrl60": "https://is1-ssl.mzstatic.com/image/thumb/Music221/v4/c8/cc/e8/c8cce868-9342-d78c-fec5-9d9e5b44106a/25UMGIM17787.rgb.jpg/60x60bb.jpg",
#       "artworkUrl100": "https://is1-ssl.mzstatic.com/image/thumb/Music221/v4/c8/cc/e8/c8cce868-9342-d78c-fec5-9d9e5b44106a/25UMGIM17787.rgb.jpg/100x100bb.jpg",
#       "releaseDate": "2025-02-18T12:00:00Z",
#       "collectionExplicitness": "notExplicit",
#       "trackExplicitness": "notExplicit",
#       "discCount": 1,
#       "discNumber": 1,
#       "trackCount": 1,
#       "trackNumber": 1,
#       "trackTimeMillis": 147000,
#       "country": "USA",
#       "currency": "USD",
#       "primaryGenreName": "Pop",
#       "isStreamable": true
#     }
#   ]
# }

# %%
import requests


def main():
    artist = input("Which artist would you like to search for? ")

    try:
        content = requests.get(
            "https://api.artic.edu/api/v1/artworks/search", {"q": artist}
        )
        content.raise_for_status()
    except requests.HTTPError:
        print("An error occurred while fetching the data.")
        return

    for artwork in content.json()["data"]:
        print(f"* {artwork["title"]}")


main()
