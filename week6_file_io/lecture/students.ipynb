# %%
with open("students.csv") as file:
    for line in file:
        row = line.strip().split(",")
        if len(row) == 2:
            print(f"{row[0]} is in {row[1]}")
# Out:
# Hermione is in Gryffindor
# Harry is in Gryffindor
# Ron is in Gryffindor
# Draco is in Slytherin
# Luna is in Ravenclaw
# Neville is in Gryffindor
# Ginny is in Gryffindor

# %%
students = []

with open("students.csv") as file:
    for line in file:
        row = line.strip().split(",")
        if len(row) == 2:
            name, house = row
            student = {"name": name, "house": house}
            students.append(student)


def get_name(student):
    return student["name"]


for student in sorted(students, key=get_name):
    print(f"{student['name']} is in {student['house']}")
# Out:
# Draco is in Slytherin
# Ginny is in Gryffindor
# Harry is in Gryffindor
# Hermione is in Gryffindor
# Luna is in Ravenclaw
# Neville is in Gryffindor
# Ron is in Gryffindor

# %%
students = []

with open("students.csv") as file:
    for line in file:
        row = line.strip().split(",")
        if len(row) == 2:
            name, house = row
            student = {"name": name, "house": house}
            students.append(student)


def get_house(student):
    return student["house"]


for student in sorted(students, key=get_house):
    print(f"{student['name']} is in {student['house']}")
# Out:
# Hermione is in Gryffindor
# Harry is in Gryffindor
# Ron is in Gryffindor
# Neville is in Gryffindor
# Ginny is in Gryffindor
# Luna is in Ravenclaw
# Draco is in Slytherin

# %%
students = []

with open("students.csv") as file:
    for line in file:
        row = line.strip().split(",")
        if len(row) == 2:
            name, house = row
            students.append({"name": name, "house": house})

for student in sorted(students, key=lambda student: student["name"]):
    print(f"{student['name']} is in {student['house']}")
# Out:
# Draco is in Slytherin
# Ginny is in Gryffindor
# Harry is in Gryffindor
# Hermione is in Gryffindor
# Luna is in Ravenclaw
# Neville is in Gryffindor
# Ron is in Gryffindor

# %%
import csv

students = []

with open("students_home.csv") as file:
    reader = csv.reader(file)
    for row in reader:
        if len(row) >= 2:
            name = row[0]
            home = ", ".join(row[1:])
            students.append({"name": name, "home": home})

for student in sorted(students, key=lambda student: student["name"]):
    print(f"{student['name']} is from {student['home']}")
# Out:
# Draco is from Malfoy Manor
# Ginny is from The Burrow
# Harry is from Number 4,  Privet Drive
# Hermione is from Number 12,  Grimmauld Place
# Luna is from The Lovegood House
# Neville is from The Longbottom House
# Ron is from The Burrow

# %%
import csv

students = []

with open("students_home.csv") as file:
    reader = csv.DictReader(file)
    for row in reader:
        students.append({"name": row["name"], "home": row["home"]})

for student in sorted(students, key=lambda student: student["name"]):
    print(f"{student['name']} is from {student['home']}")
# Out:
# Draco is from Malfoy Manor
# Ginny is from The Burrow
# Harry is from Number 4, Privet Drive
# Hermione is from Number 12
# Luna is from The Lovegood House
# Neville is from The Longbottom House
# Ron is from The Burrow

# %%
import csv

name = input("what is your name? ")
home = input("where are you from? ")

with open("students_home.csv", "a") as file:
    writer = csv.writer(file)
    writer.writerow([name, home])

# %%
import csv

name = input("what is your name? ")
home = input("where are you from? ")

with open("students_home.csv", "a") as file:
    writer = csv.DictWriter(file, fieldnames=["name", "home"])
    writer.writerow({"name": name, "home": home})
